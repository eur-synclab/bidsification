# %% [markdown]
# # Turning PAR/REC data into BIDS format using bidsify
# ### written by Eduard Klapwijk, with input from Philip Brandner, Suzanne van de Groep, Myrna van den Berg
#
# This notebook can be used to convert data with PAR/REC images (MRI image format generated by Philips scanners) into BIDS. The first step of this notebook will show you how to structure your data into pseudoBIDS format. After this, we use the bidsify tool (https://github.com/NILAB-UvA/bidsify) created by Lukas Snoek to convert the pseudoBIDS data into BIDS.
#
# All kudos should go to the bidsify creators, this is just a guide that allows the usage of bidsify with an interactive notebook. When turning my own data (Eduard) into BIDS I got great help at Neurohackademy 2019 (https://neurohackademy.org).
#
# For more information on BIDS visit https://bids.neuroimaging.io and read the Gorgolewski et al. paper about the BIDS format here: https://doi.org/10.1038/sdata.2016.44
# Another useful resource is the BIDS starter kit: https://github.com/bids-standard/bids-starter-kit
#
# There are multiple tools out there to convert datasets into Nifti (one of the main ones being Heudiconv: https://github.com/nipy/heudiconv). We use bidsify because this is as far as I am aware the only converter capable of working with PAR/REC files. Edit May 2020: I recently found out about BIDScoin (https://github.com/Donders-Institute/bidscoin), that should also be able to convert PAR/REC into BIDS.

# %% [markdown]
# ## Step 1: figure out scan sequence, rename files accordingly
#
# Our situation:
# We have a longitudinal dataset with 3 timepoints (T1, T2, T3). For every timepoint we have participant folders with scans in par/rec format. The filenames contain the participant ID, and a number for the scan sequence (but because sometimes scans are restarted this number is not always the same for a particular sequence). It looks something like this:

# %% [markdown]
#     /projectname/data/
#                     ├── T1/
#                     |   ├── BT1P0001/
#                     |   |   ├── BT1P0001_4_1.PAR
#                     |   |   ├── BT1P0001_4_1.REC
#                     |   |   ├── BT1P0001_5_1.PAR
#                     |   |   ├── BT1P0001_5_1.REC
#                     |   |   ├── BT1P0001_12_1.PAR
#                     |   |   └── BT1P0001_12_1.REC
#                     |   ├── BT1P0002/
#                     |   |   ├── BT1P0002_3_1.PAR
#                     |   |   ├── BT1P0002_3_1.REC
#                     |   |   ├── BT1P0002_4_1.PAR
#                     |   |   ├── BT1P0002_4_1.REC
#                     |   |   ├── BT1P0002_10_1.PAR
#                     |   |   └── BT1P0002_10_1.REC
#                     |   └── BT1P0345/
#                     |       ├── BT1P0345_3_1.PAR
#                     |       ├── BT1P0345_3_1.REC
#                     |       ├── BT1P0345_9_1.PAR
#                     |       └── BT1P0345_9_1.REC
#                     ├── T2/
#                     |   ├── BT2P0001/
#                     |   |   ├── BT2P0001_4_1.PAR
#                     |   |   ├── BT2P0001_4_1.REC
#                     |   |   ├── BT2P0001_6_1.PAR
#                     |   |   ├── BT2P0001_6_1.REC
#                     |   |   ├── BT2P0001_10_1.PAR
#                     |   |   └── BT2P0001_10_1.REC
#                     |   └── BT2P0345/
#                     |       ├── BT1P0345_4_1.PAR
#                     |       ├── BT1P0345_4_1.REC
#                     |       ├── BT1P0345_11_1.PAR
#                     |       └── BT1P0345_11_1.REC
#                     |
#                     └── T3/
#                         ├── BT3P0001/
#                         |   ├── et cetera
#                         et cetera

# %% [markdown]
# For every timepoint we want to rename the files to reflect what kind of scan it is (e.g, T1-weighted, task, rsfmri). It might also be a good idea to copy the files to a new location, so that we do not have to change the original raw data.
#
# First we have to define the old directory (with the raw data) and the new dir
# Here it is for timepoint 1. We can change it later and do the same for timepoint 2 and timepoint 3
#
# *Note*: you have to change all the directories in the next box that have a red color to make sure that you can use this notebook.

# %%
import os
import sys
import shutil
import glob
from pathlib import Path

rawDir = '/projectname/data/T1'
# it is useful to have one base directory, in which we have the raw (but renamed) data, 
                                                # and later the pseudobids and bids data
base_dir = os.chdir('/projectname/data/bidsify/')
rerawDir = '/projectname/data/bidsify/raw/T1'
pseudoDir = '/projectname/data/bidsify/pseudobids'

# %%
import os
import sys
import shutil
import glob
from pathlib import Path

rawDir = '/Users/eduardklapwijk/surfdrive/Postdoc/BT'
# it is useful to have one base directory, in which we have the raw (but renamed) data, 
                                                # and later the pseudobids and bids data
base_dir = '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/'
rerawDir = '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1'
pseudoDir = '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids'

# %% [markdown]
# We check whether the rerawDir already exists. If not, it will be made

# %%
newp = Path(rerawDir)
if not Path.exists(newp):
    Path(newp).mkdir(parents = True)

# %% [markdown]
# ### make subdirectories in newDir
#
# We make a list with all the dirs with data in the rawDir
# Here we restrict it using directory.startswith('BT') --> only dirs starting with BT will be put in the list.
# Using pathlib (which should work on Windows/Mac/Linux systems) we create the subdirectories in the rerawDir

# %%
dirlist = []
for root, directories, filenames in os.walk(rawDir):
    for directory in directories:
        if directory.startswith('BT'):
            dirlist.append(directory) 
            
            #create copies of the subdirectories in the newDir directory
            if not Path.exists(newp/directory):
                Path(newp/directory).mkdir()
            
print(dirlist)
# Out:
# ['BT1P0540', 'BT1P0392', 'BT1P0566']

# %% [markdown]
# ### Rename and copy files
# We have a loop that loops through the directories and files in the root directory.
# When a file is found:
# 1. its protocollines are inspected for different protocols (e.g., rsfMRI, 3DT1) in the line. *Note*: in our case the protocol description is on the 14th line, you might have to change this
# 2. the file is copied to the new directory
# 3. the file is renamed if the name does not exist yet (we always put a 5-digit identifier such as T1mri, btask, rsfmr at the end of the filename to make it easier to work with the filenames later on).
#
# *Note*: in our case, different tasks have the same protocol name ('fMRI 210 SENSE'), but in other cases there might be a more useful protocolname that denotes the kind of task. In that case it would be helpful to change this in the code to more specific names.

# %%
for root, directories, filenames in os.walk(rawDir):
    if filenames != []:
        for file in filenames:
            # extract the file name and path
            name = root + '/' + file
            name = name.replace("\\", "/")
            
            if file[-4:] == '.PAR':
                # open and read the protocolline needed for renaming
                with open(name, 'r') as f:
                    protocolline = f.readlines()
                
                # check what sort of file it is and setup the rename accordingly
                if '3DT1' in protocolline[13]:
                    rename = rerawDir + '/' + root[-8:] + '/' + file[:-4] + '_T1mri' + file[-4:]
                    # Make sure we copy and rename the files in(to) the correct path
                    WhichtoChange = rerawDir + '/' + root[-8:] + '/' + file
                    print('We found a 3DT1 file: ' + file)
                
                elif 'fMRI 210 SENSE' in protocolline[13]:
                    rename = rerawDir + '/' + root[-8:] + '/' + file[:-4] + '_btask' + file[-4:] 
                    WhichtoChange = rerawDir + '/' + root[-8:] + '/' + file
                    print('We found a btask file: ' + file)
                    
                elif 'rsfMRI' in protocolline[13]:
                    rename = rerawDir + '/' + root[-8:] + '/' + file[:-4] + '_rsfmr' + file[-4:]
                    WhichtoChange = rerawDir + '/' + root[-8:] + '/' + file
                    print('We found a rsfmri file: ' + file)
                
                elif 'hires' in protocolline[13]:
                    rename = rerawDir + '/' + root[-8:] + '/' + file[:-4] + '_T2str' + file[-4:]
                    WhichtoChange = rerawDir + '/' + root[-8:] + '/' + file
                    print('We found a T2* file: ' + file)
                
                else:
                    dontRename = file[:-4]
                    continue
                    
            
                # copy and rename the files in the new folder 
                # (gives warning if the file name already exists in the newDir)
                if not os.path.isfile(rename):
                    shutil.copy(str(name), str((rerawDir + '/' + root[-8:])))
                    os.rename(WhichtoChange, rename)
                else:
                    print('WARNING: file ' + rename + ' already exists in the folder! This file will therefore be skipped!')
# Out:
# We found a 3DT1 file: BT1P0540_10_1.PAR
# We found a btask file: BT1P0540_9_1.PAR
# We found a T2* file: BT1P0540_11_1.PAR
# We found a btask file: BT1P0540_8_1.PAR
# We found a rsfmri file: BT1P0540_4_1.PAR
# We found a btask file: BT1P0540_6_1.PAR
# We found a btask file: BT1P0540_7_1.PAR
# We found a 3DT1 file: BT1P0392_9_1.PAR
# We found a btask file: BT1P0392_8_1.PAR
# We found a T2* file: BT1P0392_10_1.PAR
# We found a btask file: BT1P0392_6_1.PAR
# We found a rsfmri file: BT1P0392_4_1.PAR
# We found a btask file: BT1P0392_7_1.PAR
# We found a 3DT1 file: BT1P0566_9_1.PAR
# We found a btask file: BT1P0566_8_1.PAR
# We found a btask file: BT1P0566_6_1.PAR
# We found a rsfmri file: BT1P0566_4_1.PAR
# We found a btask file: BT1P0566_7_1.PAR
# We found a T2* file: BT1P0566_10_1.PAR

# %% [markdown]
# ### Copy and rename REC files
#
# Next, we rename the .REC files based on the corresponding .PAR files (assuming that apart from the extension, they have exactly the same name)
# We will print whether a specific type of file is found, and to where it will be copied

# %%
for root, directories, filenames in os.walk(rerawDir):
    if filenames != []:
        for file in filenames:
            #extract the file name and path
            name = root + '\\' + file
            name = name.replace("\\", "/")
             
            if file[-4:] == '.PAR':
                numberPAR = file[-14:-10]
                typePAR = file[-9:-4]
                print('we found a ' + typePAR + ' file')
                nameREC = rawDir + '/' +  file[:8] + '/' + file[:-10] + '.REC'
                renameREC = name[:-4] + '.REC'
                
            else:
                dontRename = file[:-4]
                continue
                
            if not os.path.isfile(renameREC):
                print('REC file will be copied and renamed: ' + renameREC)
                shutil.copy(str(nameREC), str(renameREC))
                
            else:
                print('WARNING: file ' + renameREC + ' already exists in the folder! This file will therefore be skipped!')
# Out:
# we found a btask file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0540/BT1P0540_9_1_btask.REC
# we found a T1mri file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0540/BT1P0540_10_1_T1mri.REC
# we found a rsfmr file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0540/BT1P0540_4_1_rsfmr.REC
# we found a btask file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0540/BT1P0540_6_1_btask.REC
# we found a btask file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0540/BT1P0540_8_1_btask.REC
# we found a btask file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0540/BT1P0540_7_1_btask.REC
# we found a T2str file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0540/BT1P0540_11_1_T2str.REC
# we found a btask file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0392/BT1P0392_7_1_btask.REC
# we found a T2str file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0392/BT1P0392_10_1_T2str.REC
# we found a btask file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0392/BT1P0392_8_1_btask.REC
# we found a rsfmr file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0392/BT1P0392_4_1_rsfmr.REC
# we found a btask file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0392/BT1P0392_6_1_btask.REC
# we found a T1mri file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0392/BT1P0392_9_1_T1mri.REC
# we found a btask file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0566/BT1P0566_8_1_btask.REC
# we found a btask file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0566/BT1P0566_7_1_btask.REC
# we found a T1mri file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0566/BT1P0566_9_1_T1mri.REC
# we found a T2str file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0566/BT1P0566_10_1_T2str.REC
# we found a rsfmr file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0566/BT1P0566_4_1_rsfmr.REC
# we found a btask file
# REC file will be copied and renamed: /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0566/BT1P0566_6_1_btask.REC

# %% [markdown]
# #### Let's have a look at the files in our newDir:

# %%
for root, directories, filenames in os.walk(rerawDir):
    print(root) 
    for filename in filenames:
        print(filename)
# Out:
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1
# .DS_Store
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0540
# BT1P0540_9_1_btask.PAR
# BT1P0540_6_1_btask.REC
# BT1P0540_10_1_T1mri.PAR
# BT1P0540_4_1_rsfmr.REC
# BT1P0540_4_1_rsfmr.PAR
# BT1P0540_10_1_T1mri.REC
# BT1P0540_6_1_btask.PAR
# BT1P0540_9_1_btask.REC
# BT1P0540_11_1_T2str.REC
# BT1P0540_7_1_btask.REC
# BT1P0540_8_1_btask.PAR
# BT1P0540_8_1_btask.REC
# BT1P0540_7_1_btask.PAR
# BT1P0540_11_1_T2str.PAR
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0392
# BT1P0392_7_1_btask.PAR
# BT1P0392_8_1_btask.REC
# BT1P0392_10_1_T2str.REC
# BT1P0392_10_1_T2str.PAR
# BT1P0392_8_1_btask.PAR
# BT1P0392_7_1_btask.REC
# BT1P0392_9_1_T1mri.REC
# BT1P0392_4_1_rsfmr.PAR
# BT1P0392_6_1_btask.PAR
# BT1P0392_6_1_btask.REC
# BT1P0392_9_1_T1mri.PAR
# BT1P0392_4_1_rsfmr.REC
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/raw/T1/BT1P0566
# BT1P0566_8_1_btask.PAR
# BT1P0566_7_1_btask.REC
# BT1P0566_7_1_btask.PAR
# BT1P0566_8_1_btask.REC
# BT1P0566_6_1_btask.REC
# BT1P0566_9_1_T1mri.PAR
# BT1P0566_4_1_rsfmr.REC
# BT1P0566_10_1_T2str.PAR
# BT1P0566_10_1_T2str.REC
# BT1P0566_9_1_T1mri.REC
# BT1P0566_4_1_rsfmr.PAR
# BT1P0566_6_1_btask.PAR

# %% [markdown]
# ## Step 2: Rename participants and put data in pseudoBIDS format
#
# ### You can use the code below to make a list with all your participant names in the rerawDir.
#
# Assuming that your directories contain all the participant names, this can be easily done.
# Note that we strip the name and only use the number (to make it timepoint agnostic)

# %%
dirlist2 = []
for root, directories, filenames in os.walk(rerawDir):
    for directory in directories:
        if directory.startswith('BT'):
            dirlist2.append(directory[4:8]) 

print(dirlist2)
# Out:
# ['0540', '0392', '0566']

# %% [markdown]
# We make the pseudobids dir (if it does not exist yet)
# Next, using this list we do the following:
# For every participant we make a new folder with different sessions underneath (which resembles the bids format). So previously we had T1, T2, T3, we now call these ses-01, ses-02, ses-03 and they are nested within participants.
# After running the code, the structure looks like this:
#
#     /projectname/data/bidsify/pseudobids/
#                                     ├── sub-BTP0001/
#                                     |            ├── ses-01/
#                                     |            ├── ses-02/
#                                     |            └── ses-03/
#                                     ├── sub-BTP0002/
#                                     |            ├── ses-01/
#                                     |            ├── ses-02/
#                                     |            └── ses-03/
#                                     ├── sub-BTP0345/
#                                     |            ├── ses-01/
#                                     |            ├── ses-02/
#                                     |            └── ses-03/
#                                     └── sub-etcetera/
#                                                  ├── ses-01/
#                                                  ├── ses-02/
#                                                  └── ses-03/

# %%
prefix = 'sub-BTP'
newp2 = Path(pseudoDir)

# make pseudoDir
if not Path.exists(newp2):
    Path(newp2).mkdir(parents = True)

# make participant folders
for folder in dirlist2:
    folder = folder.strip()
    if not Path.exists(newp2/(prefix + str(folder))/(str('ses-01'))):
        Path(newp2/(prefix + str(folder))/(str('ses-01'))).mkdir(parents=True)
        print(newp2/(prefix + str(folder))/(str('ses-01')))
    if not Path.exists(newp2/(prefix + str(folder))/(str('ses-02'))):
        Path(newp2/(prefix + str(folder))/(str('ses-02'))).mkdir(parents=True)
        print(newp2/(prefix + str(folder))/(str('ses-02')))
    if not Path.exists(newp2/(prefix + str(folder))/(str('ses-03'))):
        Path(newp2/(prefix + str(folder))/(str('ses-03'))).mkdir(parents=True)
        print(newp2/(prefix + str(folder))/(str('ses-03')))
# Out:
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-02
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-03
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-01
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-02
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-03
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-01
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-02
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-03

# %% [markdown]
# Let's use the code below to check the directories in our pseudoDir, now we should see a list of participants directories followed by a list of session directories (note that you can check this also in Windows Explorer / Finder if you find this helpful).

# %%
for root, directories, filenames in os.walk(pseudoDir):
    print(root)
# Out:
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-02
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-03
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-01
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-02
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-03
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-02
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-03
# /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-01

# %% [markdown]
# ### Now use the code below to place every PAR/REC file you want to convert to BIDS format, in the correct sub-directories (e.g. subject/ses-01 dir).
#
# Note that you have to specify the correct names of your t1 scans and functional scans (for each run) below. You can do that by replacing the file names in red. Note that the file names should contain stars ('*') at the start and the end to make sure that the code runs for all participants (i.e. you only specify what the filenames of all participants have in common).
#
# In this step, we also add the 'bold' suffix to all bold scans. This will help bidsify to find the correct files later

# %%
prefix = 'sub-BTP'
for root, directories, filenames in os.walk(rerawDir):
    if filenames != []:
        for file in filenames:
            #extract the file name and path
            name = root + '/' + file
            name = name.replace("\\", "/")
            dest_bold = os.path.join(pseudoDir, prefix + file[4:8] + '/' + 'ses-01' + '/' + \
                                     file[:-4] + '_bold' + file[-4:])
            dest = os.path.join(pseudoDir, prefix + file[4:8] + '/' + 'ses-01' + '/' + file)


            if file[-9:-4] == 'btask' or file[-9:-4] == 'rsfmr':
                if not os.path.isfile(dest_bold):
                    print('copied file to:' + dest_bold)
                    shutil.copy(name, dest_bold)
                else:
                    print('WARNING: file ' + dest_bold + ' already exists in the folder! This file will therefore be skipped!')
            elif file[-9:-4] == 'T1mri' or file[-9:-4] == 'T2str':
                if not os.path.isfile(dest):
                    print('copied file to:' + dest)
                    shutil.copy(name, dest)
                else:
                    print('WARNING: file ' + dest + ' already exists in the folder! This file will therefore be skipped!')
# Out:
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01/BT1P0540_9_1_btask_bold.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01/BT1P0540_6_1_btask_bold.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01/BT1P0540_10_1_T1mri.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01/BT1P0540_4_1_rsfmr_bold.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01/BT1P0540_4_1_rsfmr_bold.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01/BT1P0540_10_1_T1mri.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01/BT1P0540_6_1_btask_bold.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01/BT1P0540_9_1_btask_bold.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01/BT1P0540_11_1_T2str.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01/BT1P0540_7_1_btask_bold.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01/BT1P0540_8_1_btask_bold.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01/BT1P0540_8_1_btask_bold.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01/BT1P0540_7_1_btask_bold.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0540/ses-01/BT1P0540_11_1_T2str.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-01/BT1P0392_7_1_btask_bold.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-01/BT1P0392_8_1_btask_bold.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-01/BT1P0392_10_1_T2str.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-01/BT1P0392_10_1_T2str.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-01/BT1P0392_8_1_btask_bold.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-01/BT1P0392_7_1_btask_bold.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-01/BT1P0392_9_1_T1mri.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-01/BT1P0392_4_1_rsfmr_bold.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-01/BT1P0392_6_1_btask_bold.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-01/BT1P0392_6_1_btask_bold.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-01/BT1P0392_9_1_T1mri.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0392/ses-01/BT1P0392_4_1_rsfmr_bold.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-01/BT1P0566_8_1_btask_bold.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-01/BT1P0566_7_1_btask_bold.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-01/BT1P0566_7_1_btask_bold.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-01/BT1P0566_8_1_btask_bold.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-01/BT1P0566_6_1_btask_bold.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-01/BT1P0566_9_1_T1mri.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-01/BT1P0566_4_1_rsfmr_bold.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-01/BT1P0566_10_1_T2str.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-01/BT1P0566_10_1_T2str.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-01/BT1P0566_9_1_T1mri.REC
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-01/BT1P0566_4_1_rsfmr_bold.PAR
# copied file to:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids/sub-BTP0566/ses-01/BT1P0566_6_1_btask_bold.PAR

# %% [markdown]
# #### We can check the files in the pseudobids directories to see if this went well:

# %%
for root, directories, filenames in os.walk(pseudoDir):
    for directory in directories:
        print(directory)
    for filename in filenames:
        print(filename)
# Out:
# sub-BTP0566
# sub-BTP0540
# sub-BTP0392
# .DS_Store
# ses-02
# ses-03
# ses-01
# .DS_Store
# BT1P0566_4_1_rsfmr_bold.REC
# .DS_Store
# BT1P0566_4_1_rsfmr_bold.PAR
# BT1P0566_8_1_btask_bold.REC
# BT1P0566_9_1_T1mri.PAR
# BT1P0566_6_1_btask_bold.PAR
# BT1P0566_7_1_btask_bold.REC
# BT1P0566_10_1_T2str.PAR
# BT1P0566_10_1_T2str.REC
# BT1P0566_7_1_btask_bold.PAR
# BT1P0566_6_1_btask_bold.REC
# BT1P0566_9_1_T1mri.REC
# BT1P0566_8_1_btask_bold.PAR
# ses-02
# ses-03
# ses-01
# .DS_Store
# BT1P0540_4_1_rsfmr_bold.PAR
# .DS_Store
# BT1P0540_10_1_T1mri.PAR
# BT1P0540_10_1_T1mri.REC
# BT1P0540_4_1_rsfmr_bold.REC
# BT1P0540_11_1_T2str.REC
# BT1P0540_6_1_btask_bold.REC
# BT1P0540_8_1_btask_bold.PAR
# BT1P0540_9_1_btask_bold.REC
# BT1P0540_7_1_btask_bold.PAR
# BT1P0540_7_1_btask_bold.REC
# BT1P0540_9_1_btask_bold.PAR
# BT1P0540_8_1_btask_bold.REC
# BT1P0540_11_1_T2str.PAR
# BT1P0540_6_1_btask_bold.PAR
# ses-02
# ses-03
# ses-01
# .DS_Store
# BT1P0392_4_1_rsfmr_bold.REC
# .DS_Store
# BT1P0392_10_1_T2str.REC
# BT1P0392_10_1_T2str.PAR
# BT1P0392_4_1_rsfmr_bold.PAR
# BT1P0392_7_1_btask_bold.REC
# BT1P0392_9_1_T1mri.REC
# BT1P0392_6_1_btask_bold.PAR
# BT1P0392_8_1_btask_bold.REC
# BT1P0392_8_1_btask_bold.PAR
# BT1P0392_6_1_btask_bold.REC
# BT1P0392_9_1_T1mri.PAR
# BT1P0392_7_1_btask_bold.PAR

# %% [markdown]
# ## Step 3: Install BIDSify to turn pseudoBIDS data into BIDS format
#
# For this step we first have to install bidsify and its dependencies.
#
# This is what we have to do:
# 1. Install bidsify:
# pip install bidsify
# 2. Install / check dependencies:
# dcm2niix (release v1.0.20181125 or newer)
# nibabel
# scipy
# numpy
# joblib (for parallelization)
# pandas
# 3. Make a config-file in either the json or YAML format.

# %% [markdown]
# ### Step 3.1: Install bidsify + most dependencies (see for more info https://github.com/NILAB-UvA/bidsify)

# %%
# Install bidsify package in the current Jupyter kernel
# !pip install bidsify
# Out:
# Requirement already satisfied: bidsify in /Users/eduardklapwijk/opt/anaconda3/lib/python3.7/site-packages (0.3.7)
# Requirement already satisfied: numpy in /Users/eduardklapwijk/opt/anaconda3/lib/python3.7/site-packages (from bidsify) (1.18.1)
# Requirement already satisfied: nibabel in /Users/eduardklapwijk/opt/anaconda3/lib/python3.7/site-packages (from bidsify) (3.0.2)
# Requirement already satisfied: pyyaml in /Users/eduardklapwijk/opt/anaconda3/lib/python3.7/site-packages (from bidsify) (5.3)
# Requirement already satisfied: joblib in /Users/eduardklapwijk/opt/anaconda3/lib/python3.7/site-packages (from bidsify) (0.14.1)
# Requirement already satisfied: pandas in /Users/eduardklapwijk/opt/anaconda3/lib/python3.7/site-packages (from bidsify) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/eduardklapwijk/opt/anaconda3/lib/python3.7/site-packages (from pandas->bidsify) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/eduardklapwijk/opt/anaconda3/lib/python3.7/site-packages (from pandas->bidsify) (2019.3)
# Requirement already satisfied: six>=1.5 in /Users/eduardklapwijk/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas->bidsify) (1.14.0)

# %% [markdown]
# ### Step 3.2: Install dcm2niix

# %% [markdown]
# On local machine install using Conda:

# %%
# !conda install --yes -c conda-forge dcm2niix
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# If you work on a high performance cluster you should install dcm2niix on the cluster.
# I did the following on the Shark HPC that we use (https://git.lumc.nl/shark/shark-centos-slurm-user-guide/-/wikis/home). Install it in your user or user/jupyter folder (copy code outside of this notebook):

# %%
#### installing dcm2niix on Shark:
cd /home/jupyter/bin
git clone https://github.com/rordenlab/dcm2niix.git
cd dcm2niix
mkdir build && cd build
# to avoid the error when using make .., do: 
cmake -DUSE_STATIC_RUNTIME=OFF ..
make
# finally copy binary to user/bin:
cp dcmniix etklapwijk/bin

# %% [markdown]
# ### Step 3.3: install bids-validator

# %%
pip install bids_validator
# Out:
# Collecting bids_validator
#   Downloading bids_validator-1.5.2-py2.py3-none-any.whl (14 kB)
# Installing collected packages: bids-validator
# Successfully installed bids-validator-1.5.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Step 4: Run Bidsify command to turn data into BIDS format

# %% [markdown]
# ### Step 4.1: Make a config-file in either the json or YAML format
#
# In order to run the bidsify script we have to make a config-file in either the json or YAML format. This file contains information about the experiment, such as the types and names of the anatomical and functional scans. The bidsify script needs this information to strucure the data according to the BIDS format. You will have to create this json file yourself as it is specific for each functional MRI task. You can find an example here: https://github.com/eduardklap/braindev-nipype/blob/master/config.json.
#
# We'll go for json. We can either use R package 'jsonlite' or use http://jsoneditoronline.org. See https://github.com/NILAB-UvA/bidsify#the-config-file for details.
# Place the file in the current directory --> see example ./config.json

# %%
with open(base_dir + '/config.json', 'r') as config:
    print(config.read())
# Out:
# {
#     "options":  {
#           "mri_ext": "PAR",
#           "debug": true,
#           "subject_stem": "sub",
#           "deface": false,
#           "spinoza_data": false,
#           "out_dir": "final"
#         },
#       "mappings": {
#           "bold": "bold",
#           "T1w": "T1mri",
#           "T2w": "T2str"
#         },
#       "metadata": {
#           "MagneticFieldStrength": 3,
#           "InstitutionName": "SYNC lab, Erasmus University, Rotterdam, The Netherlands"
#         },
#       "func": {
#         "gambling-run1": {
#             "id": "btask",
#             "task": "gambling",
#             "run": 1
#           },
#           "gambling-run2":{
#               "id": "btask",
#               "task": "gambling",
#               "run": 2
#             },
#           "gambling-run3": {
#               "id": "btask",
#               "task": "gambling",
#               "run": 3
#           },
#           "gambling-run4":{
#               "id": "btask",
#               "task": "gambling",
#               "run": 4
#           },
#           "task-rest":{
#               "id": "rsfmr",
#               "task": "rest"
#             }
#           },
#         "anat": {
#           "T1": {
#           "id": "T1mri"
#           },
#           "T2": {
#             "id": "T2str"
#           }
#         }
# }

# %% [markdown]
# ## Step 4: Run Bidsify command to turn data into BIDS format
# see https://github.com/NILAB-UvA/bidsify#how-does-it-work for details
#
# To run the bidsify script, you have to replace the path to your .json file and pseudobids directory below with the path to your own json file and pseudobids directory.

# %%
# !bidsify -c /projectname/data/bidsify/config.json \
-d /projectname/data/bidsify/pseudobids

# %%
# !bidsify -c /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/config.json \
-d /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids
# Out:
# Setting output-dir to /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids
# Running bidsify with the following arguments:
# 	 directory=/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/pseudobids
# 	 config=/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/config.json
# 	 out_dir=/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids
# 	 validate=False
#
# /Users/eduardklapwijk/opt/anaconda3/lib/python3.7/site-packages/bidsify/main.py:371: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(config)
# Converting data from sub-BTP0392 ... (ses-01)
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Warning: Reported TR=2200ms, measured TR=6600ms (prospect. motion corr.?)
# Done reading PAR header version 4.2, with 336 slices
# Philips Scaling Values RS:RI:SS = 10.9543:0:0.00126709 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_10_1_T2str (112x112x84x4)
# Conversion required 0.034320 seconds (0.034318 for core code).
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Done reading PAR header version 4.2, with 5320 slices
# Philips Scaling Values RS:RI:SS = 8.9851:0:0.00116455 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_4_1_rsfmr_bold (80x80x38x140)
# Conversion required 0.310190 seconds (0.307592 for core code).
# Found 153.474 vols (5832 slices) for file BT1P0392_6_1_btask_bold.PAR, but expected 210 dyns (7980 slices); going to try to fix it by removing slices from the PAR header ...
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Done reading PAR header version 4.2, with 5814 slices
# Philips Scaling Values RS:RI:SS = 5.75238:0:0.00131448 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_6_1_btask_bold (80x80x38x153)
# Conversion required 0.342187 seconds (0.341485 for core code).
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Done reading PAR header version 4.2, with 7980 slices
# Philips Scaling Values RS:RI:SS = 4.50623:0:0.00131448 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_8_1_btask_bold (80x80x38x210)
# Conversion required 0.442643 seconds (0.440106 for core code).
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Done reading PAR header version 4.2, with 140 slices
# Philips Scaling Values RS:RI:SS = 1.52283:0:0.000534654 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_9_1_T1mri (256x256x140x1)
# Conversion required 0.080482 seconds (0.080156 for core code).
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Done reading PAR header version 4.2, with 7980 slices
# Philips Scaling Values RS:RI:SS = 4.52381:0:0.00131448 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_7_1_btask_bold (80x80x38x210)
# Conversion required 0.473186 seconds (0.471985 for core code).
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_8_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/func/sub-BTP0392_ses-01_task-gambling_run-1_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_8_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/func/sub-BTP0392_ses-01_task-gambling_run-1_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_7_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/func/sub-BTP0392_ses-01_task-gambling_run-1_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_7_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/func/sub-BTP0392_ses-01_task-gambling_run-1_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_6_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/func/sub-BTP0392_ses-01_task-gambling_run-1_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_6_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/func/sub-BTP0392_ses-01_task-gambling_run-1_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_7_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/func/sub-BTP0392_ses-01_task-gambling_run-2_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_7_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/func/sub-BTP0392_ses-01_task-gambling_run-2_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_6_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/func/sub-BTP0392_ses-01_task-gambling_run-2_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_6_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/func/sub-BTP0392_ses-01_task-gambling_run-2_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_6_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/func/sub-BTP0392_ses-01_task-gambling_run-3_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_6_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/func/sub-BTP0392_ses-01_task-gambling_run-3_bold.json'
# Could not find files for element gambling-run4 (dtype func) with identifier 'btask'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_4_1_rsfmr_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/func/sub-BTP0392_ses-01_task-rest_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_4_1_rsfmr_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/func/sub-BTP0392_ses-01_task-rest_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_9_1_T1mri.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/anat/sub-BTP0392_ses-01_T1w.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_9_1_T1mri.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/anat/sub-BTP0392_ses-01_T1w.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_10_1_T2str.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/anat/sub-BTP0392_ses-01_T2w.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/BT1P0392_10_1_T2str.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0392/ses-01/anat/sub-BTP0392_ses-01_T2w.json'
# Converting data from sub-BTP0392 ... (ses-02)
# Converting data from sub-BTP0392 ... (ses-03)
# Converting data from sub-BTP0540 ... (ses-01)
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Warning: Distance between slices reported by slice gap+thick does not match estimate from slice positions (issue 273).
# Done reading PAR header version 4.2, with 5320 slices
# Philips Scaling Values RS:RI:SS = 8.05324:0:0.00117484 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_4_1_rsfmr_bold (80x80x38x140)
# Conversion required 0.298205 seconds (0.296765 for core code).
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Done reading PAR header version 4.2, with 140 slices
# Philips Scaling Values RS:RI:SS = 1.35458:0:0.000505552 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_10_1_T1mri (256x256x140x1)
# Conversion required 0.070163 seconds (0.070028 for core code).
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Warning: Distance between slices reported by slice gap+thick does not match estimate from slice positions (issue 273).
# Done reading PAR header version 4.2, with 7980 slices
# Philips Scaling Values RS:RI:SS = 7.06496:0:0.00134744 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_8_1_btask_bold (80x80x38x210)
# Conversion required 0.474418 seconds (0.470157 for core code).
# Found 18.184 vols (691 slices) for file BT1P0540_7_1_btask_bold.PAR, but expected 210 dyns (7980 slices); going to try to fix it by removing slices from the PAR header ...
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Warning: Distance between slices reported by slice gap+thick does not match estimate from slice positions (issue 273).
# Done reading PAR header version 4.2, with 684 slices
# Philips Scaling Values RS:RI:SS = 7.22637:0:0.00134744 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_7_1_btask_bold (80x80x38x18)
# Conversion required 0.043409 seconds (0.043233 for core code).
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Warning: Distance between slices reported by slice gap+thick does not match estimate from slice positions (issue 273).
# Done reading PAR header version 4.2, with 7980 slices
# Philips Scaling Values RS:RI:SS = 5.06081:0:0.00134744 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_9_1_btask_bold (80x80x38x210)
# Conversion required 0.505387 seconds (0.499374 for core code).
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Warning: Reported TR=2200ms, measured TR=6600ms (prospect. motion corr.?)
# Done reading PAR header version 4.2, with 336 slices
# Philips Scaling Values RS:RI:SS = 7.56068:0:0.0012829 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_11_1_T2str (112x112x84x4)
# Conversion required 0.031740 seconds (0.031682 for core code).
# Found 150.263 vols (5710 slices) for file BT1P0540_6_1_btask_bold.PAR, but expected 210 dyns (7980 slices); going to try to fix it by removing slices from the PAR header ...
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Warning: Distance between slices reported by slice gap+thick does not match estimate from slice positions (issue 273).
# Done reading PAR header version 4.2, with 5700 slices
# Philips Scaling Values RS:RI:SS = 6.95092:0:0.00134744 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_6_1_btask_bold (80x80x38x150)
# Conversion required 0.354944 seconds (0.346348 for core code).
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_7_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-1_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_6_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-1_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_9_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-1_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_8_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-1_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_9_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-1_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_6_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-1_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_8_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-1_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_7_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-1_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_6_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-2_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_8_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-2_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_9_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-2_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_6_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-2_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_8_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-2_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_7_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-2_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_8_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-3_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_9_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-3_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_8_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-3_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_7_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-3_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_9_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-4_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_7_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-gambling_run-4_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_4_1_rsfmr_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-rest_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_4_1_rsfmr_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/func/sub-BTP0540_ses-01_task-rest_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_10_1_T1mri.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/anat/sub-BTP0540_ses-01_T1w.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_10_1_T1mri.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/anat/sub-BTP0540_ses-01_T1w.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_11_1_T2str.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/anat/sub-BTP0540_ses-01_T2w.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/BT1P0540_11_1_T2str.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0540/ses-01/anat/sub-BTP0540_ses-01_T2w.json'
# Converting data from sub-BTP0540 ... (ses-02)
# Converting data from sub-BTP0540 ... (ses-03)
# Converting data from sub-BTP0566 ... (ses-01)
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Warning: Distance between slices reported by slice gap+thick does not match estimate from slice positions (issue 273).
# Done reading PAR header version 4.2, with 5320 slices
# Philips Scaling Values RS:RI:SS = 27.9507:0:0.00114542 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_4_1_rsfmr_bold (80x80x38x140)
# Conversion required 0.338578 seconds (0.321673 for core code).
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Done reading PAR header version 4.2, with 140 slices
# Philips Scaling Values RS:RI:SS = 1.59878:0:0.00041708 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_9_1_T1mri (256x256x140x1)
# Conversion required 0.079538 seconds (0.079331 for core code).
# Found 147.868 vols (5619 slices) for file BT1P0566_6_1_btask_bold.PAR, but expected 210 dyns (7980 slices); going to try to fix it by removing slices from the PAR header ...
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Warning: Distance between slices reported by slice gap+thick does not match estimate from slice positions (issue 273).
# Done reading PAR header version 4.2, with 5586 slices
# Philips Scaling Values RS:RI:SS = 30.9985:0:0.00129061 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_6_1_btask_bold (80x80x38x147)
# Conversion required 0.362265 seconds (0.345106 for core code).
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Warning: Reported TR=2200ms, measured TR=6600ms (prospect. motion corr.?)
# Done reading PAR header version 4.2, with 336 slices
# Philips Scaling Values RS:RI:SS = 8.14432:0:0.00124244 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_10_1_T2str (112x112x84x4)
# Conversion required 0.042250 seconds (0.042241 for core code).
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Warning: Distance between slices reported by slice gap+thick does not match estimate from slice positions (issue 273).
# Done reading PAR header version 4.2, with 7980 slices
# Philips Scaling Values RS:RI:SS = 36.3665:0:0.00129061 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_7_1_btask_bold (80x80x38x210)
# Conversion required 0.502804 seconds (0.491937 for core code).
# Compression will be faster with 'pigz' installed http://macappstore.org/pigz/
# Chris Rorden's dcm2niiX version v1.0.20190902  Clang4.0.1 (64-bit MacOS)
# Warning: dcm2niix PAR is not actively supported (hint: use dicm2nii)
# Warning: Distance between slices reported by slice gap+thick does not match estimate from slice positions (issue 273).
# Done reading PAR header version 4.2, with 7980 slices
# Philips Scaling Values RS:RI:SS = 44.5338:0:0.00129061 (see PMC3998685)
# Convert 1 DICOM as /Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_8_1_btask_bold (80x80x38x210)
# Conversion required 0.457465 seconds (0.454176 for core code).
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_8_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/func/sub-BTP0566_ses-01_task-gambling_run-1_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_7_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/func/sub-BTP0566_ses-01_task-gambling_run-1_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_7_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/func/sub-BTP0566_ses-01_task-gambling_run-1_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_8_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/func/sub-BTP0566_ses-01_task-gambling_run-1_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_6_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/func/sub-BTP0566_ses-01_task-gambling_run-1_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_6_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/func/sub-BTP0566_ses-01_task-gambling_run-1_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_7_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/func/sub-BTP0566_ses-01_task-gambling_run-2_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_8_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/func/sub-BTP0566_ses-01_task-gambling_run-2_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_6_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/func/sub-BTP0566_ses-01_task-gambling_run-2_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_6_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/func/sub-BTP0566_ses-01_task-gambling_run-2_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_6_1_btask_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/func/sub-BTP0566_ses-01_task-gambling_run-3_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_6_1_btask_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/func/sub-BTP0566_ses-01_task-gambling_run-3_bold.nii'
# Could not find files for element gambling-run4 (dtype func) with identifier 'btask'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_4_1_rsfmr_bold.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/func/sub-BTP0566_ses-01_task-rest_bold.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_4_1_rsfmr_bold.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/func/sub-BTP0566_ses-01_task-rest_bold.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_9_1_T1mri.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/anat/sub-BTP0566_ses-01_T1w.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_9_1_T1mri.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/anat/sub-BTP0566_ses-01_T1w.nii'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_10_1_T2str.json' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/anat/sub-BTP0566_ses-01_T2w.json'
# Renaming '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/BT1P0566_10_1_T2str.nii' to '/Users/eduardklapwijk/surfdrive/Postdoc/bidsify/bids/sub-BTP0566/ses-01/anat/sub-BTP0566_ses-01_T2w.nii'
# Converting data from sub-BTP0566 ... (ses-02)
# Converting data from sub-BTP0566 ... (ses-03)

# %% [markdown]
# We rename the T2w to T2star (for more clarity, and according to bids specifications)
# In the bidsify package there is currently no T2star mapping (as far as I aware), therefore we simply rename the files in this step.

# %%
for root, directories, filenames in os.walk(base_dir + '/bids'):
    if filenames != []:
        for file in filenames:
            #extract the file name and path
            name = root + '/' + file
            name = name.replace("\\", "/")
            #renameT2nii = root + '/' + file[:-7] + 'T2star' + file[-4:]
            #renameT2js = root + '/' + file[:-8] + 'T2star' + file[-5:]
            #print(name)
            if 'T2w.nii' in file:
                renameT2nii = root + '/' + file[:-7] + 'T2star' + file[-4:]
                if not os.path.isfile(renameT2nii):
                    print('renamenii:' + renameT2nii)
                    os.rename(name, renameT2nii)
                else:
                    print('WARNING: file ' + renameT2nii + ' already exists in the folder! This file will therefore be skipped!')
            if 'T2w.json' in file:
                renameT2js = root + '/' + file[:-8] + 'T2star' + file[-5:]
                if not os.path.isfile(renameT2js):
                    print('renamejs:' + renameT2js)
                    os.rename(name, renameT2js)
                else:
                    print('WARNING: file ' + renameT2js + ' already exists in the folder! This file will therefore be skipped!')
# Out:
# renamejs:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify//bids/sub-BTP0566/ses-01/anat/sub-BTP0566_ses-01_T2star.json
# renamenii:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify//bids/sub-BTP0566/ses-01/anat/sub-BTP0566_ses-01_T2star.nii
# renamenii:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify//bids/sub-BTP0540/ses-01/anat/sub-BTP0540_ses-01_T2star.nii
# renamejs:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify//bids/sub-BTP0540/ses-01/anat/sub-BTP0540_ses-01_T2star.json
# renamenii:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify//bids/sub-BTP0392/ses-01/anat/sub-BTP0392_ses-01_T2star.nii
# renamejs:/Users/eduardklapwijk/surfdrive/Postdoc/bidsify//bids/sub-BTP0392/ses-01/anat/sub-BTP0392_ses-01_T2star.json

# %% [markdown]
# ### If everything went well, we now have a new directory called 'bids' with our data in BIDS format
# Let's have a look:

# %%
for root, directories, filenames in os.walk(base_dir + '/bids'):
    for directory in directories:
        print(directory)
    for filename in filenames:
        print(filename)
# Out:
# sub-BTP0566
# sub-BTP0540
# sub-BTP0392
# .DS_Store
# dataset_description.json
# participants.tsv
# ses-02
# ses-03
# ses-01
# anat
# func
# sub-BTP0566_ses-01_T2star.json
# sub-BTP0566_ses-01_T1w.json
# sub-BTP0566_ses-01_T2star.nii
# sub-BTP0566_ses-01_T1w.nii
# sub-BTP0566_ses-01_task-rest_bold.json
# sub-BTP0566_ses-01_task-gambling_run-1_bold.json
# sub-BTP0566_ses-01_task-gambling_run-1_bold.nii
# sub-BTP0566_ses-01_task-rest_bold.nii
# sub-BTP0566_ses-01_task-gambling_run-3_bold.json
# sub-BTP0566_ses-01_task-gambling_run-2_bold.nii
# sub-BTP0566_ses-01_task-gambling_run-3_bold.nii
# sub-BTP0566_ses-01_task-gambling_run-2_bold.json
# ses-02
# ses-03
# ses-01
# anat
# func
# sub-BTP0540_ses-01_T2star.json
# sub-BTP0540_ses-01_T2star.nii
# sub-BTP0540_ses-01_T1w.nii
# sub-BTP0540_ses-01_T1w.json
# sub-BTP0540_ses-01_task-gambling_run-2_bold.nii
# sub-BTP0540_ses-01_task-gambling_run-3_bold.nii
# sub-BTP0540_ses-01_task-gambling_run-1_bold.json
# sub-BTP0540_ses-01_task-rest_bold.nii
# sub-BTP0540_ses-01_task-gambling_run-4_bold.nii
# sub-BTP0540_ses-01_task-gambling_run-1_bold.nii
# sub-BTP0540_ses-01_task-gambling_run-3_bold.json
# sub-BTP0540_ses-01_task-gambling_run-4_bold.json
# sub-BTP0540_ses-01_task-gambling_run-2_bold.json
# sub-BTP0540_ses-01_task-rest_bold.json
# ses-02
# ses-03
# ses-01
# .DS_Store
# anat
# func
# .DS_Store
# sub-BTP0392_ses-01_T1w.nii
# sub-BTP0392_ses-01_T2star.nii
# sub-BTP0392_ses-01_T2star.json
# sub-BTP0392_ses-01_T1w.json
# sub-BTP0392_ses-01_task-gambling_run-1_bold.nii
# sub-BTP0392_ses-01_task-gambling_run-1_bold.json
# sub-BTP0392_ses-01_task-rest_bold.nii
# sub-BTP0392_ses-01_task-gambling_run-2_bold.json
# sub-BTP0392_ses-01_task-rest_bold.json
# sub-BTP0392_ses-01_task-gambling_run-2_bold.nii
# sub-BTP0392_ses-01_task-gambling_run-3_bold.nii
# sub-BTP0392_ses-01_task-gambling_run-3_bold.json

# %% [markdown]
# ### To add here: BIDS validator in the notebook to validate whether everything is correct

# %%
# need to make this work for the whole dataset, check fmriprep source code
from bids_validator import BIDSValidator

BIDSValidator().is_bids(base_dir + '/bids')
# Out:
# False
